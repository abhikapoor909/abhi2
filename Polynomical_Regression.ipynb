# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=6 * np.random.rand(100,1)-3
y=0.5 *x**2+1.5*x+2+np.random.rand(100,1)

# %%
plt.scatter(x,y)

# %%
print("hello world")
# Out:
# hello world
