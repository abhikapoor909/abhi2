# %%
import pandas as pd
import numpy as np

df=pd.read_csv("matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df.describe() #works only on numerical values
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
y=df["winner"]
y #this is series not dataframe; 
## this is 1D
# Out:
# 0             Kolkata Knight Riders
# 1               Chennai Super Kings
# 2                  Delhi Daredevils
# 3       Royal Challengers Bangalore
# 4             Kolkata Knight Riders
#                    ...
# 1090            Sunrisers Hyderabad
# 1091          Kolkata Knight Riders
# 1092               Rajasthan Royals
# 1093            Sunrisers Hyderabad
# 1094          Kolkata Knight Riders
# Name: winner, Length: 1095, dtype: object

# %%
y=df[["winner","team1","team2"]] #for fetching multiple coloumns, this is dataframe

# %%
type(y) ## THIS IS 2D
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0] ## this will fetch the 1st row
# Out:
# id                                      335982
# season                                 2007/08
# city                                 Bangalore
# date                                2008-04-18
# match_type                              League
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# target_runs                              223.0
# target_overs                              20.0
# super_over                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# ...

# %%
df.iloc[1:5,[0,1]] # to fetch rows and columns both
# Out:
#        id   season
# 1  335983  2007/08
# 2  335984  2007/08
# 3  335985  2007/08
# 4  335986  2007/08

# %%
mask=df["city"]=="Bangalore"

# %%
df[mask].head() ## for filtering the values
# Out:
#         id   season       city        date match_type player_of_match  \
# 0   335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 10  335992  2007/08  Bangalore  2008-04-26     League       SR Watson
# 14  335996  2007/08  Bangalore  2008-04-28     League        MS Dhoni
# 21  336034  2007/08  Bangalore  2008-05-03     League         P Kumar
# 24  336006  2007/08  Bangalore  2008-05-05     League     S Sreesanth
#
#                     venue                        team1                  team2  \
# 0   M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 10  M Chinnaswamy Stadium  Royal Challengers Bangalore       Rajasthan Royals
# 14  M Chinnaswamy Stadium  Royal Challengers Bangalore    Chennai Super Kings
# 21  M Chinnaswamy Stadium  Royal Challengers Bangalore        Deccan Chargers
# 24  M Chinnaswamy Stadium  Royal Challengers Bangalore        Kings XI Punjab
#
# ...

# %%
df[df["city"]=="Bangalore"].reset_index().head() ## different way to filter
# Out:
#    index      id   season       city        date match_type player_of_match  \
# 0      0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1     10  335992  2007/08  Bangalore  2008-04-26     League       SR Watson
# 2     14  335996  2007/08  Bangalore  2008-04-28     League        MS Dhoni
# 3     21  336034  2007/08  Bangalore  2008-05-03     League         P Kumar
# 4     24  336006  2007/08  Bangalore  2008-05-05     League     S Sreesanth
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore       Rajasthan Royals
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore    Chennai Super Kings
# 3  M Chinnaswamy Stadium  Royal Challengers Bangalore        Deccan Chargers
# 4  M Chinnaswamy Stadium  Royal Challengers Bangalore        Kings XI Punjab
#
# ...

# %%
mask1=df["city"]=="Bangalore"
mask2=df["date"]>="2010-01-01"

# %%
df[mask1 & mask2].reset_index().head() ## used bitwise end because the return type of these mask variables is boolen
# Out:
#    index      id   season       city        date match_type player_of_match  \
# 0    121  419112  2009/10  Bangalore  2010-03-16     League       JH Kallis
# 1    124  419115  2009/10  Bangalore  2010-03-18     League       JH Kallis
# 2    132  419123  2009/10  Bangalore  2010-03-23     League      RV Uthappa
# 3    135  419128  2009/10  Bangalore  2010-03-25     League       KM Jadhav
# 4    154  419145  2009/10  Bangalore  2010-04-08     League        TL Suman
#
#                    venue                        team1                team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore      Kings XI Punjab
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore     Rajasthan Royals
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Chennai Super Kings
# 3  M Chinnaswamy Stadium  Royal Challengers Bangalore     Delhi Daredevils
# 4  M Chinnaswamy Stadium  Royal Challengers Bangalore      Deccan Chargers
#
# ...

# %%
abhi=df["winner"].value_counts()

# %%
type(abhi)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
abhi=df["winner"].value_counts().plot(kind="bar")
