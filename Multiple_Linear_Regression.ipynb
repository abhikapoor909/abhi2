# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=df.drop(df.columns[2],axis=1)

df.head()

df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df=pd.read_csv("Student_Performance.csv")

# %%
x=df[["Previous Scores","Sleep Hours"]]
y=df["Performance Index"]

# %%
x.head()
# Out:
#    Previous Scores  Sleep Hours
# 0               99            9
# 1               82            4
# 2               51            7
# 3               52            5
# 4               75            8

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
import seaborn as sns

# %%
sns.regplot(x="Hours Studied", y="Performance Index", data=df)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
z=StandardScaler()
x_train=z.fit_transform(x_train)
x_test=z.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([34.81321847, 35.32189884, 33.80229877, ..., 40.38293841,
#        46.4420156 , 60.0862111 ])

# %%
acc= r2_score(y_test,y_pred)
print(f"Model Accuracy: {acc}")
# Out:
# Model Accuracy: 0.8419653574998436
